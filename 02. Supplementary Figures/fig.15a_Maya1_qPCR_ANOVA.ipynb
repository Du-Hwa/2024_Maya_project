# %%
##### Load packages #####
library(tidyverse)
library(multcomp)
library(ggplot2)
# Load CSV
graphdata <- read.csv("01.UGT76B1.csv")

# Reshape the data from wide to long format
graphdata_long <- graphdata %>%
  gather(column, value)

graphdata_long <- na.omit(graphdata_long)
graphdata_long$column <- factor(graphdata_long$column)

# Extract unique values of "column" variable and preserve order
x_order <- unique(graphdata_long$column)

# Perform one-way ANOVA
res.aov <- aov(value ~ column, data = graphdata_long)
print(summary(res.aov))
tukey_result <- glht(res.aov, linfct = mcp(column = "Tukey"))
multcomps <- cld(tukey_result)
print(multcomps)
print(summary(tukey_result))
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: mvtnorm
#
# Loading required package: survival
#
# Loading required package: TH.data
#
# Loading required package: MASS
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
#
# Attaching package: ‘TH.data’
#
#
# The following object is masked from ‘package:MASS’:
#
#     geyser
#
#
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '01.UGT76B1.csv'”
#             Df Sum Sq Mean Sq F value   Pr(>F)
# column       3  56.34  18.779   35.31 3.11e-06 ***
# Residuals   12   6.38   0.532
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   WT_Maya1   WT_flg22 fls2_Maya1 fls2_flg22
#        "a"        "b"        "b"        "b"
#
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = value ~ column, data = graphdata_long)
#
# Linear Hypotheses:
#                              Estimate Std. Error t value Pr(>|t|)
# WT_flg22 - WT_Maya1 == 0      -4.0952     0.5156  -7.942   <1e-04 ***
# fls2_Maya1 - WT_Maya1 == 0    -4.5545     0.5156  -8.833   <1e-04 ***
# fls2_flg22 - WT_Maya1 == 0    -4.3016     0.5156  -8.342   <1e-04 ***
# fls2_Maya1 - WT_flg22 == 0    -0.4593     0.5156  -0.891    0.810
# fls2_flg22 - WT_flg22 == 0    -0.2064     0.5156  -0.400    0.977
# fls2_flg22 - fls2_Maya1 == 0   0.2529     0.5156   0.490    0.960
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)

# %%
##### Load packages #####
library(tidyverse)
library(multcomp)
library(ggplot2)
# Load CSV
graphdata <- read.csv("02.BLGU18.csv")

# Reshape the data from wide to long format
graphdata_long <- graphdata %>%
  gather(column, value)

graphdata_long <- na.omit(graphdata_long)
graphdata_long$column <- factor(graphdata_long$column)

# Extract unique values of "column" variable and preserve order
x_order <- unique(graphdata_long$column)

# Perform one-way ANOVA
res.aov <- aov(value ~ column, data = graphdata_long)
print(summary(res.aov))
tukey_result <- glht(res.aov, linfct = mcp(column = "Tukey"))
multcomps <- cld(tukey_result)
print(multcomps)
print(summary(tukey_result))
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '02.BLGU18.csv'”
#             Df Sum Sq Mean Sq F value   Pr(>F)
# column       3  3.996  1.3321   26.88 1.31e-05 ***
# Residuals   12  0.595  0.0496
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   WT_Maya1   WT_flg22 fls2_Maya1 fls2_flg22
#        "a"        "b"        "b"        "b"
#
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = value ~ column, data = graphdata_long)
#
# Linear Hypotheses:
#                              Estimate Std. Error t value Pr(>|t|)
# WT_flg22 - WT_Maya1 == 0     -1.17473    0.15742  -7.462   <1e-04 ***
# fls2_Maya1 - WT_Maya1 == 0   -1.18827    0.15742  -7.548   <1e-04 ***
# fls2_flg22 - WT_Maya1 == 0   -1.08953    0.15742  -6.921   <1e-04 ***
# fls2_Maya1 - WT_flg22 == 0   -0.01354    0.15742  -0.086    1.000
# fls2_flg22 - WT_flg22 == 0    0.08520    0.15742   0.541    0.947
# fls2_flg22 - fls2_Maya1 == 0  0.09874    0.15742   0.627    0.921
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)

# %%
##### Load packages #####
library(tidyverse)
library(multcomp)
library(ggplot2)
# Load CSV
graphdata <- read.csv("03.CYP79B3.csv")

# Reshape the data from wide to long format
graphdata_long <- graphdata %>%
  gather(column, value)

graphdata_long <- na.omit(graphdata_long)
graphdata_long$column <- factor(graphdata_long$column)

# Extract unique values of "column" variable and preserve order
x_order <- unique(graphdata_long$column)

# Perform one-way ANOVA
res.aov <- aov(value ~ column, data = graphdata_long)
print(summary(res.aov))
tukey_result <- glht(res.aov, linfct = mcp(column = "Tukey"))
multcomps <- cld(tukey_result)
print(multcomps)
print(summary(tukey_result))
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '03.CYP79B3.csv'”
#             Df Sum Sq Mean Sq F value   Pr(>F)
# column       3  6.303  2.1010   12.71 0.000491 ***
# Residuals   12  1.983  0.1653
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   WT_Maya1   WT_flg22 fls2_Maya1 fls2_flg22
#        "a"        "b"        "b"        "b"
#
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = value ~ column, data = graphdata_long)
#
# Linear Hypotheses:
#                              Estimate Std. Error t value Pr(>|t|)
# WT_flg22 - WT_Maya1 == 0      -1.6085     0.2874  -5.596  < 0.001 ***
# fls2_Maya1 - WT_Maya1 == 0    -1.2286     0.2874  -4.274  0.00512 **
# fls2_flg22 - WT_Maya1 == 0    -1.4105     0.2874  -4.907  0.00161 **
# fls2_Maya1 - WT_flg22 == 0     0.3798     0.2874   1.321  0.56768
# fls2_flg22 - WT_flg22 == 0     0.1979     0.2874   0.689  0.89949
# fls2_flg22 - fls2_Maya1 == 0  -0.1819     0.2874  -0.633  0.91942
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)

# %%
##### Load packages #####
library(tidyverse)
library(multcomp)
library(ggplot2)
# Load CSV
graphdata <- read.csv("04.TGA.csv")

# Reshape the data from wide to long format
graphdata_long <- graphdata %>%
  gather(column, value)

graphdata_long <- na.omit(graphdata_long)
graphdata_long$column <- factor(graphdata_long$column)

# Extract unique values of "column" variable and preserve order
x_order <- unique(graphdata_long$column)

# Perform one-way ANOVA
res.aov <- aov(value ~ column, data = graphdata_long)
print(summary(res.aov))
tukey_result <- glht(res.aov, linfct = mcp(column = "Tukey"))
multcomps <- cld(tukey_result)
print(multcomps)
print(summary(tukey_result))
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '04.TGA.csv'”
#             Df Sum Sq Mean Sq F value   Pr(>F)
# column       3  8.121  2.7070   14.59 0.000263 ***
# Residuals   12  2.227  0.1856
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   WT_Maya1   WT_flg22 fls2_Maya1 fls2_flg22
#        "a"        "b"        "b"        "b"
#
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = value ~ column, data = graphdata_long)
#
# Linear Hypotheses:
#                              Estimate Std. Error t value Pr(>|t|)
# WT_flg22 - WT_Maya1 == 0     -1.74929    0.30462  -5.743  < 0.001 ***
# fls2_Maya1 - WT_Maya1 == 0   -1.54580    0.30462  -5.075  0.00142 **
# fls2_flg22 - WT_Maya1 == 0   -1.61465    0.30462  -5.301  < 0.001 ***
# fls2_Maya1 - WT_flg22 == 0    0.20349    0.30462   0.668  0.90710
# fls2_flg22 - WT_flg22 == 0    0.13463    0.30462   0.442  0.96993
# fls2_flg22 - fls2_Maya1 == 0 -0.06886    0.30462  -0.226  0.99570
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)

# %%
##### Load packages #####
library(tidyverse)
library(multcomp)
library(ggplot2)
# Load CSV
graphdata <- read.csv("05.FRK1.csv")

# Reshape the data from wide to long format
graphdata_long <- graphdata %>%
  gather(column, value)

graphdata_long <- na.omit(graphdata_long)
graphdata_long$column <- factor(graphdata_long$column)

# Extract unique values of "column" variable and preserve order
x_order <- unique(graphdata_long$column)

# Perform one-way ANOVA
res.aov <- aov(value ~ column, data = graphdata_long)
print(summary(res.aov))
tukey_result <- glht(res.aov, linfct = mcp(column = "Tukey"))
multcomps <- cld(tukey_result)
print(multcomps)
print(summary(tukey_result))
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '05.FRK1.csv'”
#             Df Sum Sq Mean Sq F value   Pr(>F)
# column       3  93.58  31.192   15.75 0.000184 ***
# Residuals   12  23.77   1.981
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   WT_Maya1   WT_flg22 fls2_Maya1 fls2_flg22
#        "a"        "a"        "b"        "b"
#
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = value ~ column, data = graphdata_long)
#
# Linear Hypotheses:
#                              Estimate Std. Error t value Pr(>|t|)
# WT_flg22 - WT_Maya1 == 0      2.02902    0.99519   2.039   0.2277
# fls2_Maya1 - WT_Maya1 == 0   -3.57869    0.99519  -3.596   0.0168 *
# fls2_flg22 - WT_Maya1 == 0   -3.63010    0.99519  -3.648   0.0152 *
# fls2_Maya1 - WT_flg22 == 0   -5.60771    0.99519  -5.635   <0.001 ***
# fls2_flg22 - WT_flg22 == 0   -5.65912    0.99519  -5.686   <0.001 ***
# fls2_flg22 - fls2_Maya1 == 0 -0.05141    0.99519  -0.052   0.9999
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)
