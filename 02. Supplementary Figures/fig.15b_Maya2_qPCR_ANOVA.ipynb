# %%
##### Load packages #####
library(tidyverse)
library(multcomp)
library(ggplot2)
# Load CSV
graphdata <- read.csv("01.NUDT4.csv")

# Numbering
graphdata <- graphdata %>% rename_with(~ paste0("0", seq_along(.), "_", .), everything())
print(graphdata)

# Reshape the data from wide to long format
graphdata_long <- graphdata %>%
  gather(column, value)

graphdata_long <- na.omit(graphdata_long)
graphdata_long$column <- factor(graphdata_long$column)

# Extract unique values of "column" variable and preserve order
x_order <- unique(graphdata_long$column)

# Perform one-way ANOVA
res.aov <- aov(value ~ column, data = graphdata_long)
print(summary(res.aov))
tukey_result <- glht(res.aov, linfct = mcp(column = "Tukey"))
multcomps <- cld(tukey_result)
print(multcomps)
print(summary(tukey_result))
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '01.NUDT4.csv'”
#   01_WT_Maya2 02_WT_flg22 03_fls2_Maya2 04_fls2_flg22
# 1    3.264588   0.1528664     0.7369934      1.060500
# 2    3.523236   0.1575435     0.8524716      1.308367
# 3    2.365100   0.1654566     1.0678608      1.280942
# 4    2.365100   0.1471247     1.1055189      1.284922
#             Df Sum Sq Mean Sq F value   Pr(>F)
# column       3 15.750   5.250   51.42 4.01e-07 ***
# Residuals   12  1.225   0.102
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   01_WT_Maya2   02_WT_flg22 03_fls2_Maya2 04_fls2_flg22
#           "a"           "b"           "c"           "c"
#
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = value ~ column, data = graphdata_long)
#
# Linear Hypotheses:
#                                    Estimate Std. Error t value Pr(>|t|)
# 02_WT_flg22 - 01_WT_Maya2 == 0      -2.7238     0.2259 -12.055  < 0.001 ***
# 03_fls2_Maya2 - 01_WT_Maya2 == 0    -1.9388     0.2259  -8.581  < 0.001 ***
# 04_fls2_flg22 - 01_WT_Maya2 == 0    -1.6458     0.2259  -7.284  < 0.001 ***
# 03_fls2_Maya2 - 02_WT_flg22 == 0     0.7850     0.2259   3.474  0.02066 *
# 04_fls2_flg22 - 02_WT_flg22 == 0     1.0779     0.2259   4.771  0.00215 **
# 04_fls2_flg22 - 03_fls2_Maya2 == 0   0.2930     0.2259   1.297  0.58192
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)

# %%
##### Load packages #####
library(tidyverse)
library(multcomp)
library(ggplot2)
# Load CSV
graphdata <- read.csv("02.STZ.csv")

# Numbering
graphdata <- graphdata %>% rename_with(~ paste0("0", seq_along(.), "_", .), everything())
print(graphdata)

# Reshape the data from wide to long format
graphdata_long <- graphdata %>%
  gather(column, value)

graphdata_long <- na.omit(graphdata_long)
graphdata_long$column <- factor(graphdata_long$column)

# Extract unique values of "column" variable and preserve order
x_order <- unique(graphdata_long$column)

# Perform one-way ANOVA
res.aov <- aov(value ~ column, data = graphdata_long)
print(summary(res.aov))
tukey_result <- glht(res.aov, linfct = mcp(column = "Tukey"))
multcomps <- cld(tukey_result)
print(multcomps)
print(summary(tukey_result))
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '02.STZ.csv'”
#   01_WT_Maya2 02_WT_flg22 03_fls2_Maya2 04_fls2_flg22
# 1    3.436348   0.2351306     0.6065598     0.7814878
# 2    3.786529   0.2446584     0.6683714     0.8054277
# 3    2.355243   0.2416440     0.6534831     0.8856901
# 4    2.197519   0.2234150     0.7151025     0.7525276
#             Df Sum Sq Mean Sq F value   Pr(>F)
# column       3 17.640   5.880   37.69 2.19e-06 ***
# Residuals   12  1.872   0.156
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   01_WT_Maya2   02_WT_flg22 03_fls2_Maya2 04_fls2_flg22
#           "a"           "b"           "b"           "b"
#
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = value ~ column, data = graphdata_long)
#
# Linear Hypotheses:
#                                    Estimate Std. Error t value Pr(>|t|)
# 02_WT_flg22 - 01_WT_Maya2 == 0      -2.7077     0.2793  -9.695   <0.001 ***
# 03_fls2_Maya2 - 01_WT_Maya2 == 0    -2.2830     0.2793  -8.174   <0.001 ***
# 04_fls2_flg22 - 01_WT_Maya2 == 0    -2.1376     0.2793  -7.654   <0.001 ***
# 03_fls2_Maya2 - 02_WT_flg22 == 0     0.4247     0.2793   1.520    0.456
# 04_fls2_flg22 - 02_WT_flg22 == 0     0.5701     0.2793   2.041    0.227
# 04_fls2_flg22 - 03_fls2_Maya2 == 0   0.1454     0.2793   0.521    0.953
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)

# %%
##### Load packages #####
library(tidyverse)
library(multcomp)
library(ggplot2)
# Load CSV
graphdata <- read.csv("03.ALD1.csv")

# Numbering
graphdata <- graphdata %>% rename_with(~ paste0("0", seq_along(.), "_", .), everything())
print(graphdata)

# Reshape the data from wide to long format
graphdata_long <- graphdata %>%
  gather(column, value)

graphdata_long <- na.omit(graphdata_long)
graphdata_long$column <- factor(graphdata_long$column)

# Extract unique values of "column" variable and preserve order
x_order <- unique(graphdata_long$column)

# Perform one-way ANOVA
res.aov <- aov(value ~ column, data = graphdata_long)
print(summary(res.aov))
tukey_result <- glht(res.aov, linfct = mcp(column = "Tukey"))
multcomps <- cld(tukey_result)
print(multcomps)
print(summary(tukey_result))
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '03.ALD1.csv'”
#   01_WT_Maya2 02_WT_flg22 03_fls2_Maya2 04_fls2_flg22
# 1    2.232964   0.9016256     1.1763227     0.3093180
# 2    1.928795   0.9415933     1.1655415     0.2957910
# 3    3.111098   0.9418919     0.5177715     0.3058182
# 4    3.025631   0.8964880     0.7543445     0.3238417
#             Df Sum Sq Mean Sq F value   Pr(>F)
# column       3 11.392   3.797   33.97 3.82e-06 ***
# Residuals   12  1.341   0.112
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   01_WT_Maya2   02_WT_flg22 03_fls2_Maya2 04_fls2_flg22
#           "a"           "b"           "b"           "b"
#
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = value ~ column, data = graphdata_long)
#
# Linear Hypotheses:
#                                    Estimate Std. Error t value Pr(>|t|)
# 02_WT_flg22 - 01_WT_Maya2 == 0      -1.6542     0.2364  -6.997   <0.001 ***
# 03_fls2_Maya2 - 01_WT_Maya2 == 0    -1.6711     0.2364  -7.069   <0.001 ***
# 04_fls2_flg22 - 01_WT_Maya2 == 0    -2.2659     0.2364  -9.585   <0.001 ***
# 03_fls2_Maya2 - 02_WT_flg22 == 0    -0.0169     0.2364  -0.072   0.9999
# 04_fls2_flg22 - 02_WT_flg22 == 0    -0.6117     0.2364  -2.587   0.0957 .
# 04_fls2_flg22 - 03_fls2_Maya2 == 0  -0.5948     0.2364  -2.516   0.1073
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)

# %%
##### Load packages #####
library(tidyverse)
library(multcomp)
library(ggplot2)
# Load CSV
graphdata <- read.csv("04.PROPEP2.csv")

# Reshape the data from wide to long format
graphdata_long <- graphdata %>%
  gather(column, value)

graphdata_long <- na.omit(graphdata_long)
graphdata_long$column <- factor(graphdata_long$column)

# Extract unique values of "column" variable and preserve order
x_order <- unique(graphdata_long$column)

# Perform one-way ANOVA
res.aov <- aov(value ~ column, data = graphdata_long)
print(summary(res.aov))
tukey_result <- glht(res.aov, linfct = mcp(column = "Tukey"))
multcomps <- cld(tukey_result)
print(multcomps)
print(summary(tukey_result))
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '04.PROPEP2.csv'”
#             Df Sum Sq Mean Sq F value   Pr(>F)
# column       3 21.180   7.060   75.74 4.57e-08 ***
# Residuals   12  1.119   0.093
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   WT_Maya2   WT_flg22 fls2_Maya2 fls2_flg22
#        "a"        "a"        "b"        "b"
#
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = value ~ column, data = graphdata_long)
#
# Linear Hypotheses:
#                              Estimate Std. Error t value Pr(>|t|)
# WT_flg22 - WT_Maya2 == 0       0.1392     0.2159   0.645    0.915
# fls2_Maya2 - WT_Maya2 == 0    -1.9586     0.2159  -9.073   <0.001 ***
# fls2_flg22 - WT_Maya2 == 0    -2.4478     0.2159 -11.339   <0.001 ***
# fls2_Maya2 - WT_flg22 == 0    -2.0978     0.2159  -9.718   <0.001 ***
# fls2_flg22 - WT_flg22 == 0    -2.5870     0.2159 -11.984   <0.001 ***
# fls2_flg22 - fls2_Maya2 == 0  -0.4892     0.2159  -2.266    0.161
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)
