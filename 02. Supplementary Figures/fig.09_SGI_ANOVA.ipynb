# %%
##### Load packages #####
library(tidyverse)
library(multcomp)
library(ggplot2)
# Load CSV
graphdata <- read.csv("ED fig.9.csv")

# Reshape the data from wide to long format
graphdata_long <- graphdata %>%
  gather(column, value)

graphdata_long <- na.omit(graphdata_long)
graphdata_long$column <- factor(graphdata_long$column)

# Extract unique values of "column" variable and preserve order
x_order <- unique(graphdata_long$column)

# Perform one-way ANOVA
res.aov <- aov(value ~ column, data = graphdata_long)
print(summary(res.aov))
tukey_result <- glht(res.aov, linfct = mcp(column = "Tukey"))
multcomps <- cld(tukey_result)
print(multcomps)
print(summary(tukey_result))
# Out:
#              Df Sum Sq Mean Sq F value Pr(>F)
# column        5  95463   19093   95.52 <2e-16 ***
# Residuals   193  38575     200
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#        X01.DMSO_WT   X02.Maya2_WT_5µM       X03.flg22_WT      X04.DMSO_fls2
#                "a"                "b"                "c"                "a"
# X05.Maya2_fls2_5µM     X06.flg22_fls2
#                "a"                "a"
#
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = value ~ column, data = graphdata_long)
#
# Linear Hypotheses:
#                                            Estimate Std. Error t value Pr(>|t|)
# X02.Maya2_WT_5µM - X01.DMSO_WT == 0         11.7606     3.4804   3.379   0.0113
# X03.flg22_WT - X01.DMSO_WT == 0             57.4545     3.4804  16.508   <0.001
# X04.DMSO_fls2 - X01.DMSO_WT == 0            -5.5303     3.4804  -1.589   0.6069
# X05.Maya2_fls2_5µM - X01.DMSO_WT == 0        1.4576     3.4804   0.419   0.9983
# X06.flg22_fls2 - X01.DMSO_WT == 0           -4.7320     3.4548  -1.370   0.7451
# X03.flg22_WT - X02.Maya2_WT_5µM == 0        45.6939     3.4804  13.129   <0.001
# X04.DMSO_fls2 - X02.Maya2_WT_5µM == 0      -17.2909     3.4804  -4.968   <0.001
# X05.Maya2_fls2_5µM - X02.Maya2_WT_5µM == 0 -10.3030     3.4804  -2.960   0.0399
# X06.flg22_fls2 - X02.Maya2_WT_5µM == 0     -16.4926     3.4548  -4.774   <0.001
# X04.DMSO_fls2 - X03.flg22_WT == 0          -62.9848     3.4804 -18.097   <0.001
# X05.Maya2_fls2_5µM - X03.flg22_WT == 0     -55.9970     3.4804 -16.089   <0.001
# X06.flg22_fls2 - X03.flg22_WT == 0         -62.1865     3.4548 -18.000   <0.001
# X05.Maya2_fls2_5µM - X04.DMSO_fls2 == 0      6.9879     3.4804   2.008   0.3417
# X06.flg22_fls2 - X04.DMSO_fls2 == 0          0.7983     3.4548   0.231   0.9999
# X06.flg22_fls2 - X05.Maya2_fls2_5µM == 0    -6.1896     3.4548  -1.792   0.4735
#
# X02.Maya2_WT_5µM - X01.DMSO_WT == 0        *
# X03.flg22_WT - X01.DMSO_WT == 0            ***
# X04.DMSO_fls2 - X01.DMSO_WT == 0
# X05.Maya2_fls2_5µM - X01.DMSO_WT == 0
# X06.flg22_fls2 - X01.DMSO_WT == 0
# X03.flg22_WT - X02.Maya2_WT_5µM == 0       ***
# X04.DMSO_fls2 - X02.Maya2_WT_5µM == 0      ***
# X05.Maya2_fls2_5µM - X02.Maya2_WT_5µM == 0 *
# X06.flg22_fls2 - X02.Maya2_WT_5µM == 0     ***
# X04.DMSO_fls2 - X03.flg22_WT == 0          ***
# X05.Maya2_fls2_5µM - X03.flg22_WT == 0     ***
# X06.flg22_fls2 - X03.flg22_WT == 0         ***
# X05.Maya2_fls2_5µM - X04.DMSO_fls2 == 0
# X06.flg22_fls2 - X04.DMSO_fls2 == 0
# X06.flg22_fls2 - X05.Maya2_fls2_5µM == 0
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)
